# %% [markdown]
# # <b>File Handling 😹</b>
# ### File handling pada Python adalah proses dalam membuat, membaca, mengubah, dan menghapus file pada sistem. Python menyediakan fungsi utama dalam file handling, yaitu ```open()```. Fungsi ```open()``` mengambil dua parameter, yaitu ```filename``` dan ```mode```.

# %% [markdown]
# ---

# %% [markdown]
# ## Mode dalam fungsi ```open()``` yang sering digunakan sebagai berikut:
# ### 1. 'r' => <b>(Read) </b> berfungsi untuk membuka dan membaca sebuah file.
# ### 2. 'a' => <b>(Append)</b> berfungsi untuk membuka file untuk ditambahkan sebuah data, jika belum ada maka Python akan membuat secara otomatis.
# ### 3. 'w' => <b>(Write)</b> berfungsi untuk membuka file untuk ditulis sebuah data, jika tidak ada maka akan dibuat secara otomatis.
#
#
# ### Setelah membuka file dengan fungsi ```open()```, kita perlu menutupnya dengan fungsi ```close()```. Tujuannya adalah untuk menjaga resource memori dan mencegah kebocoran memori.

# %% [markdown]
# ---

# %% [markdown]
# # Menyimpan data dengan database sederhana menggunakan CSV

# %% [markdown]
# ### CSV (Comma Separated Value) adalah sebuah file teks yang menyimpan data dalam format tabel terstruktur dengan memisahkan nilai-nilai menggunakan koma atau titik koma.

# %% [markdown]
# ## Mode 'r' (Read)

# %%
file = open("data_mahasiswa.csv", "r")
data = file.read()
print(data)
file.close() # tutup file setelah proses membuka file selesai
# Out:
# Nama, NIM, Jurusan
# Rasthian, 222410102000, Teknologi Informasi
# Fathan, 232410103015, Informatika

# %% [markdown]
# ## Mode 'a' (Append)

# %%
file = open('data_mahasiswa.csv', 'a')
# menambahkan data ke file csv dengan fungsi write
file.write('Nama, NIM, Jurusan\n')
file.write('Fauzul, 232410101015, Sistem Informasi\n')
file.write('Eka, 232410102004, Teknologi Informasi\n')
file.write('Taufiq, 232410103025, Informatika\n')
file.close() # tutup file setelah proses menambah data selesai

# membaca file setelah ditambahkan data menggunakan mode 'r'
file = open('data_mahasiswa.csv', 'r')
data = file.read() # membaca file setelah ditambahkan data
print(data)
file.close() # tutup file setelah proses membaca file selesai
# Out:
# Nama, NIM, Jurusan
# Fauzul, 232410101015, Sistem Informasi
# Eka, 232410102004, Teknologi Informasi
# Taufiq, 232410103025, Informatika

# %% [markdown]
# ## Mode 'w' (Write)

# %%
# file = open('data_mahasiswa.csv', 'w')
# file.write('Nama : Budiono Siregar\nNIM : 242410104100\nJurusan : Teknik Komputer dan Jaringan\n')
# file.close()

# uncomment kode berikut & lihat perbedaannya
file = open('data_mahasiswa.csv', 'w') #
file.write('Nama : Fauzul Akbar\nNIM : 242410101001\nJurusan : Sistem Informasi\n')
file.close()

file = open('data_mahasiswa.csv', 'r')
data = file.read()
print(data)
file.close()
# Out:
# Nama : Fauzul Akbar
# NIM : 242410101001
# Jurusan : Sistem Informasi

# %% [markdown]
# ### Setiap menggunakan fungsi ```open()``` untuk membuka file, kita juga harus menggunakan fungsi ```close()``` untuk menutup file.
# ### Cara lain agar dalam melakukan File Handling lebih efisien adalah dengan menggunakan statement ```with```. Statement ini memungkinkan kita melakukan File Handling secara efisien, karena setelah kita membuka file maka otomatis akan ditutup jika sudah selesai.

# %%
# Contoh penggunaan with statement
with open('data_mahasiswa.csv', 'r') as file:
    data = file.read()
    print(data)
# Out:
# Nama : Fauzul Akbar
# NIM : 242410101001
# Jurusan : Sistem Informasi

# %% [markdown]
# ## Penerapan statement 'with' dalam File Handling

# %%
# Menulis file dengan with statement menggunakan mode 'w' (write)
with open('data_mahasiswa.csv', 'w') as file:
    file.write('Nama, NIM, Jurusan\n')

# Menambahkan data ke file dengan with statement menggunakan mode 'a' (append)
with open('data_mahasiswa.csv', 'a') as file:
    file.write('Rasthian, 222410102000, Teknologi Informasi\n')
    file.write('Fathan, 232410103015, Informatika')

# Membaca file dengan with statement menggunakan mode 'r' (read)
with open('data_mahasiswa.csv', 'r') as file:
    data = file.read()
    print(data)
# Out:
# Nama, NIM, Jurusan
# Rasthian, 222410102000, Teknologi Informasi
# Fathan, 232410103015, Informatika

# %% [markdown]
# # <b>Data Handling 😽</b>

# %% [markdown]
# ![image 11.png](data:image/png;base64,...)

# %% [markdown]
# <h3>Kalo kalian punya data, kalian bisa ngatur data yang kalian punya. Entah itu mau diurutkan, ditambahin data, dihapus, diedit, dan segala macem. Pake apa kak ngaturnya? pake nanya. Pake pandas lah 🐼 </h3>

# %% [markdown]
# ![Screenshot 2024-11-05 175505.png](data:image/png;base64,...)

# %%
import pandas as pd

# %% [markdown]
# Dataframe dalam pandas memiliki parameter.Parameter ini adalah data yang akan digunakan untuk membuat DataFrame. Data bisa berupa beberapa tipe, termasuk:
#
# - ndarray: Array NumPy
# - dict: Kamus Python
# - list: Daftar Python
# - series: Series Pandas
# - DataFrame: DataFrame lainnya

# %% [markdown]
# # Membuat data

# %% [markdown]
# ### Data kosong

# %%
dataKosong = pd.DataFrame()
print(dataKosong)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Data dengan list satu dimensi

# %%
dataHewan = pd.DataFrame(['Ayam', 'Badak', 'Sapi', 'Semut'])
dataHewan
# print(dataHewan)
# Out:
#        0
# 0   Ayam
# 1  Badak
# 2   Sapi
# 3  Semut

# %% [markdown]
# ### Data dengan list dua dimensi

# %%
dataStatusHewan = [['Ayam', 'Mati'], ['Badak', 'Hidup'], ['Sapi', 'Mati'], ['Semut', 'Hidup']]
dataStatusHewan = pd.DataFrame(dataStatusHewan)
dataStatusHewan
# print(df)
# Out:
#        0      1
# 0   Ayam   Mati
# 1  Badak  Hidup
# 2   Sapi   Mati
# 3  Semut  Hidup

# %% [markdown]
# ### Menambakan nama kolom dalam data

# %%
dataOrangMasukSurga = [
    ['nama', 'umur', 'negara'],
    ['Ariski', 22, 'Denmark'],
    ['Kholish', 20, 'Japan'],
    ['Adya', 25, 'Finlandia'],
    ['Wildan', 19, 'Mars'],
    ['Agung', 23, 'Laos'],
    ['Zaki', 30, 'Qatar'],
    ['Lia', 40, 'Argentina'],
    ['Aditya', 28, 'Portugal'],
    ['Fauzul', 27, 'France'],
    ['Sefa', 24, 'Norwegia'],
    ['Tunggul', 26, 'Jombang'],
    ['Fahmi', 21, 'Spanyol']
]
header = dataOrangMasukSurga.pop(0)
dataOrangMasukSurga = pd.DataFrame(dataOrangMasukSurga, columns=header)
dataOrangMasukSurga
# Out:
#        nama  umur     negara
# 0    Ariski    22    Denmark
# 1   Kholish    20      Japan
# 2      Adya    25  Finlandia
# 3    Wildan    19       Mars
# 4     Agung    23       Laos
# 5      Zaki    30      Qatar
# 6       Lia    40  Argentina
# 7    Aditya    28   Portugal
# 8    Fauzul    27     France
# 9      Sefa    24   Norwegia
# 10  Tunggul    26    Jombang
# 11    Fahmi    21    Spanyol

# %% [markdown]
# ### Menggunakan dictionary (langsung ada headernya)

# %%
dataOrangSukses = {
    'Nama' : ['Ariski', 'Kholish', 'Adya', 'Wildan', 'Agung', 'Zaki', 'Lia', 'Aditya', 'Fauzul', 'Sefa', 'Tunggul', 'Fahmi'],
    'Perusahaan' : ['Amazon', 'NASA', 'Microsoft', 'Tesla', 'Meta', 'Tokopedia', 'Google', 'Rockstar', 'Shopee', 'Pertamina', 'OVO', 'OpenAI'],
    'Penghasilan ($)' : [10000000, 8500000, 12000000, 20000000, 18000000, 7500000, 16000000, 8000000, 9000000, 11000000, 9500000, 12500000]
}

dataOrangSukses = pd.DataFrame(dataOrangSukses)
dataOrangSukses
# print(dataOrangSukses) di file.py diawali print
# Out:
#        Nama Perusahaan  Penghasilan ($)
# 0    Ariski     Amazon         10000000
# 1   Kholish       NASA          8500000
# 2      Adya  Microsoft         12000000
# 3    Wildan      Tesla         20000000
# 4     Agung       Meta         18000000
# 5      Zaki  Tokopedia          7500000
# 6       Lia     Google         16000000
# 7    Aditya   Rockstar          8000000
# 8    Fauzul     Shopee          9000000
# 9      Sefa  Pertamina         11000000
# 10  Tunggul        OVO          9500000
# 11    Fahmi     OpenAI         12500000

# %% [markdown]
# # Menyimpan ke csv

# %%
dataOrangSukses.to_csv('dataOrangSukses.csv', index=False)

# %% [markdown]
# # Membaca data dari csv

# %% [markdown]
# File csv yang telah dibuat dapat dibaca menggunakan pd.read_csv(*file yang dituju*)

# %%
dataOrangSukses = pd.read_csv('dataOrangSukses.csv')
dataOrangSukses
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dataOrangSukses = pd.read_csv('dataOrangSukses.csv')
#       2 dataOrangSukses
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Method untuk melihat data

# %% [markdown]
# Berikut adalah beberapa metode penting untuk melihat data:
#
# *   head(): Menampilkan beberapa baris pertama data.
# *   tail(): Menampilkan beberapa baris terakhir data.
# *   info(): Menampilkan ringkasan informasi DataFrame.
# *   describe(): Memberikan statistik ringkas untuk kolom numerik.
#
# Mengubah tipe data menggunakan .astype()

# %%
dataOrangSukses.head(4) #Menampilkan 4 baris pertama
# dataOrangSukses.dtypes
dataOrangSukses.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataOrangSukses.head(4) #Menampilkan 4 baris pertama
#       2 # dataOrangSukses.dtypes
#       3 dataOrangSukses.info()
#
# NameError: name 'dataOrangSukses' is not defined

# %%
dataOrangSukses.tail(4) #Menampilkan 4 baris terakhir
# Out:
#        Nama Perusahaan  Penghasilan ($)
# 8    Fauzul     Shopee          9000000
# 9      Sefa  Pertamina         11000000
# 10  Tunggul        OVO          9500000
# 11    Fahmi     OpenAI         12500000

# %% [markdown]
# # Mengubah tipe data

# %%
dataOrangSukses = dataOrangSukses.astype({
    'Nama':'str',
    'Perusahaan':'str',
    'Penghasilan ($)':'int'
})

dataOrangSukses
# Out:
#        Nama Perusahaan  Penghasilan ($)
# 0    Ariski     Amazon         10000000
# 1   Kholish       NASA          8500000
# 2      Adya  Microsoft         12000000
# 3    Wildan      Tesla         20000000
# 4     Agung       Meta         18000000
# 5      Zaki  Tokopedia          7500000
# 6       Lia     Google         16000000
# 7    Aditya   Rockstar          8000000
# 8    Fauzul     Shopee          9000000
# 9      Sefa  Pertamina         11000000
# 10  Tunggul        OVO          9500000
# 11    Fahmi     OpenAI         12500000

# %% [markdown]
# # Melihat Informasi data

# %%
dataOrangSukses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nama             12 non-null     object
#  1   Perusahaan       12 non-null     object
#  2   Penghasilan ($)  12 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 420.0+ bytes

# %% [markdown]
# # Melihat ringkasan data

# %%
dataOrangSukses.describe()
# Out:
#        Penghasilan ($)
# count     1.200000e+01
# mean      1.183333e+07
# std       4.097301e+06
# min       7.500000e+06
# 25%       8.875000e+06
# 50%       1.050000e+07
# 75%       1.337500e+07
# max       2.000000e+07

# %% [markdown]
# # Menampilkan ukuran data

# %%
dataOrangSukses.shape # Outputnya 12 dan 3. 
# 12 untuk baris, 3 untuk kolom.
# Out:
# (12, 3)

# %% [markdown]
# # Menampilkan kolom tertentu

# %%
# dataOrangSukses.Nama # Cara pertama
# dataOrangSukses['Nama'] # Cara kedua: Outputnya mirip kek cara yang pertama
dataOrangSukses[['Nama']] # Cara kedua
# Out:
#        Nama
# 0    Ariski
# 1   Kholish
# 2      Adya
# 3    Wildan
# 4     Agung
# 5      Zaki
# 6       Lia
# 7    Aditya
# 8    Fauzul
# 9      Sefa
# 10  Tunggul
# 11    Fahmi

# %% [markdown]
# # FIltering data

# %%
dataOrangSukses.head(5)
# Out:
#       Nama Perusahaan  Penghasilan ($)
# 0   Ariski     Amazon         10000000
# 1  Kholish       NASA          8500000
# 2     Adya  Microsoft         12000000
# 3   Wildan      Tesla         20000000
# 4    Agung       Meta         18000000

# %% [markdown]
# ### Index location (iloc)

# %%
dataOrangSukses.iloc[3] #indexing berdaasrkan baris, contoh disini baris ketiga
# Out:
#      Nama Perusahaan  Penghasilan ($)
# 3  Wildan      Tesla         20000000

# %%
dataOrangSukses.iloc[3, 0:2] #baris ketiga, kolom dengan index dari 0 sampai sebelum 3
# Out:
# Nama          Wildan
# Perusahaan     Tesla
# Name: 3, dtype: object

# %%
dataOrangSukses.iloc[[2]] #filter berdasarkan baris
# Out:
#    Nama Perusahaan  Penghasilan ($)
# 2  Adya  Microsoft         12000000

# %% [markdown]
# # Merging data

# %% [markdown]
# ### Menggunakan `join()`

# %%
data1 = {
    'Nama' : ['Kambing', 'Sapi', 'Kerbau'],
    'Umur' : [3, 4, 5]
}

data2 = {
    'Alamat' : ['Jember', 'Manchester United', 'Jl. Kalimantan 9']
}

data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)

dataJoin = data1.join(data2)
dataJoin
# Out:
#       Nama  Umur             Alamat
# 0  Kambing     3             Jember
# 1     Sapi     4  Manchester United
# 2   Kerbau     5   Jl. Kalimantan 9

# %% [markdown]
# ### Menggunakan `concat()`

# %%
data1 = {
    'Nama' : ['Kambing', 'Sapi', 'Kerbau'],
    'Umur' : [3, 4, 5]
}

data2 = {
    'Alamat' : ['Jember', 'Manchester United', 'Jl. Kalimantan 9']
}

data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)

dataJoin = pd.concat([data1, data2], axis=1)
dataJoin
# Out:
#       Nama  Umur             Alamat
# 0  Kambing     3             Jember
# 1     Sapi     4  Manchester United
# 2   Kerbau     5   Jl. Kalimantan 9

# %% [markdown]
# ### Menggunakan `merge()`

# %%
data1 = {
    'Nama' : ['Kambing', 'Sapi', 'Kerbau'],
    'Umur' : [3, 4, 5]
}

data2 = {
    'NamaData1' : ['Kambing', 'Sapi', 'Kerbau'],
    'Alamat' : ['Jember', 'Manchester United', 'Jl. Kalimantan 9']    
}

data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)

dataMerge = pd.merge(left=data1, right=data2, left_on='Nama', right_on='NamaData1')
dataMerge
# Out:
#       Nama  Umur NamaData1             Alamat
# 0  Kambing     3   Kambing             Jember
# 1     Sapi     4      Sapi  Manchester United
# 2   Kerbau     5    Kerbau   Jl. Kalimantan 9

# %% [markdown]
# # Update Data

# %%
dataOrangSukses.head(5)
# Out:
#       Nama Perusahaan  Penghasilan ($)
# 0   Ariski     Amazon         10000000
# 1  Kholish       NASA          8500000
# 2     Adya  Microsoft         12000000
# 3   Wildan      Tesla         20000000
# 4    Agung       Meta         18000000

# %% [markdown]
# Misal Agung ganti perusahaan dari Meta ke Warung Barokah

# %% [markdown]
# ### Menggunakan `iloc[]`

# %%
dataOrangSukses.iloc[4, 1] = 'Warung Barokah'

# %%
dataOrangSukses.head(5)
# Out:
#       Nama      Perusahaan  Penghasilan ($)
# 0   Ariski          Amazon         10000000
# 1  Kholish            NASA          8500000
# 2     Adya       Microsoft         12000000
# 3   Wildan           Tesla         20000000
# 4    Agung  Warung Barokah         18000000

# %% [markdown]
# ### Menggunakan `at()`

# %% [markdown]
# Misal Kholish resign dari NASA terus keterima di Warung Garahan

# %%
dataOrangSukses.at[1, 'Perusahaan'] = 'Warung Garahan'

# %%
dataOrangSukses.head(5)
# Out:
#       Nama      Perusahaan  Penghasilan ($)
# 0   Ariski          Amazon         10000000
# 1  Kholish  Warung Garahan          8500000
# 2     Adya       Microsoft         12000000
# 3   Wildan           Tesla         20000000
# 4    Agung  Warung Barokah         18000000

# %% [markdown]
# # Menghapus data

# %%
database = {
    'Nama':['Naver', 'Naveria', 'Delion','Deliveria'],
    'NIM':[4000, 4001, 4002, 4003],
    'Nilai':[90.0, 90.0, 90.0, 90.0]
}

data = pd.DataFrame(database)
data
# Out:
#         Nama   NIM  Nilai
# 0      Naver  4000   90.0
# 1    Naveria  4001   90.0
# 2     Delion  4002   90.0
# 3  Deliveria  4003   90.0

# %%
data = data.drop(1)
data
# Out:
#         Nama   NIM  Nilai
# 0      Naver  4000   90.0
# 2     Delion  4002   90.0
# 3  Deliveria  4003   90.0

# %% [markdown]
# <h2>Indexnya kacaw le, benerkan dong<h2>

# %%
data.index = range(0, 2)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data.index = range(0, 2)
#       2 data
#
# NameError: name 'data' is not defined

# %% [markdown]
# #### CRUD
# Praktik dikit yh guis, mwehehe (biar paham)

# %%
import pandas as pd

def show_data():
    df = pd.read_csv('data_sederhana.csv')
    print(df)

def tambah_data():
    nama = input("Masukkan Nama: ")
    umur = int(input("Masukkan Umur: "))
    df = pd.read_csv('data_sederhana.csv')
    df = pd.concat([df, pd.DataFrame([{'Nama': nama, 'Umur': umur}])], ignore_index=True)
    df.to_csv('data_sederhana.csv', index=False)

def baca_data():
    show_data()

def ubah_data():
    nama = input("Masukkan Nama yang ingin diubah: ")
    umur_baru = int(input("Masukkan Umur baru: "))
    df = pd.read_csv('data_sederhana.csv')
    df.loc[df['Nama'] == nama, 'Umur'] = umur_baru
    df.to_csv('data_sederhana.csv', index=False)

def hapus_data():
    nama = input("Masukkan Nama yang ingin dihapus: ")
    df = pd.read_csv('data_sederhana.csv')
    df = df[df['Nama'] != nama]
    df.to_csv('data_sederhana.csv', index=False)

try:
    pd.read_csv('data_sederhana.csv')
except FileNotFoundError:
    df = pd.DataFrame({'Nama': [], 'Umur': []})
    df.to_csv('data_sederhana.csv', index=False)

while True:
    print("1. Tambah Data")
    print("2. Tampilkan Data")
    print("3. Ubah Data")
    print("4. Hapus Data")
    print("5. Keluar")
    pilihan = input("Pilih menu (1/2/3/4/5): ")
    if pilihan == '1':
        tambah_data()
    elif pilihan == '2':
        baca_data()
    elif pilihan == '3':
        ubah_data()
    elif pilihan == '4':
        hapus_data()
    elif pilihan == '5':
        break
    else:
        print("Pilihan tidak valid.")
# Out:
# 1. Tambah Data
# 2. Tampilkan Data
# 3. Ubah Data
# 4. Hapus Data
# 5. Keluar
#             Nama  Umur
# 0        Naveria    18
# 1  Naveria Works    23
# 1. Tambah Data
# 2. Tampilkan Data
# 3. Ubah Data
# 4. Hapus Data
# 5. Keluar
